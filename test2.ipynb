# %%
import pandas as pd

# %%
dic = {"a": 4, "b": 7, "c": -5, "d": 3}
s = pd.Series(dic)

s1 = pd.Series(dic,index=["a","c"],name="aacc")
print(s1)
s1
# Out:
# a    4
# c   -5
# Name: aacc, dtype: int64
# a    4
# c   -5
# Name: aacc, dtype: int64

# %%
df = pd.DataFrame(dic, index=["a", "b", "c", "d"])
df.count()
df.cummax()
# Out:
#    a  b  c  d
# a  4  7 -5  3
# b  4  7 -5  3
# c  4  7 -5  3
# d  4  7 -5  3
